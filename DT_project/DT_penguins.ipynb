# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\ml\modular\ml-class\Data\penguins_size.csv")
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df.info
# Out:
# <bound method DataFrame.info of     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
# ...

# %%
#calculate percentage of missing value
(10/344)*100
# Out:
# 2.9069767441860463

# %%
df=df.dropna()

# %%
df.info
# Out:
# <bound method DataFrame.info of     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
# ...

# %%
#total of 10 rows has been droped
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
df["island"].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df["sex"].unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
#we have to define "." some value (here we  are not doing imputation)

# %%
df[df['sex'] == '.']
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
df[df['species'] == 'Gentoo'].groupby('sex').describe().transpose()
#compare the mean w.r.t different features to compare sex and predicting the sex of Gentoo species
# Out:
# sex                           .       FEMALE         MALE
# culmen_length_mm  count     1.0    58.000000    61.000000
#                   mean     44.5    45.563793    49.473770
#                   std       NaN     2.051247     2.720594
#                   min      44.5    40.900000    44.400000
#                   25%      44.5    43.850000    48.100000
#                   50%      44.5    45.500000    49.500000
#                   75%      44.5    46.875000    50.500000
#                   max      44.5    50.500000    59.600000
# culmen_depth_mm   count     1.0    58.000000    61.000000
#                   mean     15.7    14.237931    15.718033
#                   std       NaN     0.540249     0.741060
#                   min      15.7    13.100000    14.100000
#                   25%      15.7    13.800000    15.200000
#                   50%      15.7    14.250000    15.700000
#                   75%      15.7    14.600000    16.100000
# ...

# %%
df.at[336,"sex"]="FEMALE"

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
sns.scatterplot(x="culmen_length_mm",y="culmen_depth_mm",data=df,hue="species",palette="dark")
# Out:
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.pairplot(df,hue="species",palette="dark")

# %%
sns.catplot(x="species",y="culmen_length_mm",data=df,kind="box")

# %%
sns.catplot(x = 'species', y = 'culmen_length_mm', col = 'sex', data = df, kind = 'box')

# %%
X = pd.get_dummies(df.drop('species', axis =1), drop_first = True)    # imputation

# %%
y = df['species']

# %%
df.shape
# Out:
# (334, 7)

# %%
# TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
#hear we don't do feature scaling  as we are not taking all features same time

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model_preds = model.predict(X_test)
model_preds
# Out:
# array(['Chinstrap', 'Gentoo', 'Adelie', 'Chinstrap', 'Gentoo',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Adelie', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo',
#        'Adelie', 'Adelie', 'Adelie', 'Gentoo', 'Chinstrap', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Chinstrap', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Gentoo',
#        'Gentoo', 'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap', 'Gentoo',
#        'Adelie', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie', 'Chinstrap',
#        'Gentoo', 'Chinstrap', 'Chinstrap', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
# ...

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix

# %%
print(classification_report(y_test, model_preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.91      0.95      0.93        41
#    Chinstrap       0.90      0.83      0.86        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.94       101
#    macro avg       0.94      0.93      0.93       101
# weighted avg       0.94      0.94      0.94       101

# %%
plot_confusion_matrix(model, X_test, y_test)
# Out:
# c:\Users\HP\Anaconda3\envs\ml_Test\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
model.feature_importances_
# Out:
# array([0.32352044, 0.04203954, 0.54282921, 0.01325074, 0.0681854 ,
#        0.01017467, 0.        ])

# %%
X.columns
# Out:
# Index(['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
#        'body_mass_g', 'island_Dream', 'island_Torgersen', 'sex_MALE'],
#       dtype='object')

# %%
pd.DataFrame(index=X.columns,data=model.feature_importances_,columns=['Feature Importance']).sort_values('Feature Importance')
# Out:
#                    Feature Importance
# sex_MALE                     0.000000
# island_Torgersen             0.010175
# body_mass_g                  0.013251
# culmen_depth_mm              0.042040
# island_Dream                 0.068185
# culmen_length_mm             0.323520
# flipper_length_mm            0.542829

# %%
#it showa that the flipper_length is most weighted feature  and 
# it will take it as root note ,but see the data set that there are other features witch are also important

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(dpi=150)
plot_tree(model); #using default parameters

# %%
len(X_train)
# Out:
# 233

# %%
plt.figure(dpi = 200)
plot_tree(model, feature_names = X.columns, filled = True);

# %%
pruned_tree = DecisionTreeClassifier(max_depth =3)

# %%
pruned_tree.fit(X_train, y_train) #2nd DT Model
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
model_pred = pruned_tree.predict(X_test)

# %%
def report_model(model): #Exploring the Hyperparameters
    print(classification_report(y_test, model_pred))
    print('\n')
    plt.figure(dpi = 200)
    plot_tree(model, feature_names = X.columns, filled = True);

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %%
# To check the maximum no of leaf nodes

max_leaf_tree = DecisionTreeClassifier(max_leaf_nodes = 3) #3rd DT Model
max_leaf_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=3)

# %%
model3_pred = max_leaf_tree.predict(X_test)

# %%
print(classification_report(y_test, model3_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.88      0.92        41
#    Chinstrap       0.83      0.87      0.85        23
#       Gentoo       0.93      1.00      0.96        37
#
#     accuracy                           0.92       101
#    macro avg       0.91      0.92      0.91       101
# weighted avg       0.92      0.92      0.92       101

# %%
plt.figure(dpi = 200)
plot_tree(max_leaf_tree, feature_names = X.columns, filled = True);

# %%
entropy_tree = DecisionTreeClassifier(criterion = 'entropy') #4th Model

# %%
entropy_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
model4_pred = entropy_tree.predict(X_test)

# %%
print(classification_report(y_test, model4_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      0.98      0.98        41
#    Chinstrap       0.96      0.96      0.96        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.98       101
#    macro avg       0.98      0.98      0.98       101
# weighted avg       0.98      0.98      0.98       101

# %%
plt.figure(dpi = 200)
plot_tree(entropy_tree, feature_names = X.columns, filled = True);
